# %% [markdown]
# <a href="https://colab.research.google.com/github/veroorli/ProjetProg/blob/master/tp1_xpath.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # TP Xpath 1.0

# %% [markdown]
# **Attention:** la librairie XML utilisée dans ce TP fournit XPath 1.0 et il faut utiliser des fonctions XPath ou Python pour obtenir l'expressivité de XPath 2.0.
#
# https://www.w3.org/TR/1999/REC-xpath-19991116/
#
# https://lxml.de/

# %%
# !pip install lxml
# !pip install graphviz
# !pip install pydotplus
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: lxml in /home/cel/.local/lib/python3.8/site-packages (4.5.2)
# WARNING: You are using pip version 21.1.3; however, version 21.2.4 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: graphviz in /home/cel/.local/lib/python3.8/site-packages (0.16)
# WARNING: You are using pip version 21.1.3; however, version 21.2.4 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pydotplus in /home/cel/.local/lib/python3.8/site-packages (2.0.2)
# Requirement already satisfied: pyparsing>=2.0.1 in /usr/lib/python3/dist-packages (from pydotplus) (2.4.6)
# WARNING: You are using pip version 21.1.3; however, version 21.2.4 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
import io
import pydotplus
from lxml import etree
from copy import deepcopy
from graphviz import Source
from IPython.display import display, Image
from rdflib.tools.rdf2dot import rdf2dot

# %% [markdown]
# ### Fonctions d'affichage

# %%
def printXML(element):
    t=etree.ElementTree(element)
    print(etree.tostring(t, pretty_print=True, encoding='unicode'))
 
        
def printXPath(xmltree,xp):
    r=xmltree.xpath(xp)
    for x in r:
        if isinstance(x,str):
            if x.is_text:
                print(x)
            if x.is_attribute:
                print(x.getparent().attrib)
        elif isinstance(x,float):
            print(x)
        else:
            printXML(x)

def displayXPath(xmltree,xp,pngfile="reponse"):
    r=xmltree.xpath(xp)
    reponse=etree.Element("reponse", xpath=xp)
    for x in r:
        reponse.append(deepcopy(x))
    displayXMLInline(reponse)

    
def displayXML(t,pngfile="test"):
    f_xslt = open("xslt/xml2dot.xslt","r")
    xslt=etree.parse(f_xslt)
    transform = etree.XSLT(xslt)
    s_dot=transform(t)
    s=Source(s_dot,filename="gendata/"+pngfile+".dot", format="png")
    s.view()
    
def displayXMLInline(t):
    f_xslt = open("xslt/xml2dot.xslt","r")
    xslt=etree.parse(f_xslt)
    transform = etree.XSLT(xslt)
    s_dot=transform(t)
    dg = pydotplus.graph_from_dot_data(str(s_dot))
    png = dg.create_png()
    display(Image(png))

# %% [markdown]
# ### Lecture des documents XML

# %%
# ouvrir les fichiers XML
f1 = open("data/roisdefrance.xml","r")
f2 = open("data/roisdefranceplat.xml","r")
# parser les documents
tree1=etree.parse(f1)
tree2=etree.parse(f2)

# %% [markdown]
# ### Affichage graphique des documents xml
# nécessite l'installation de graphviz (https://graphviz.org/)
# * Linux : sudo apt install graphviz
# * Windows : http://graphviz.org/download

# %%
displayXMLInline(tree1)

# %%
displayXMLInline(tree2)

# %% [markdown]
# **Exercice:** Evaluez les expressions XPath suivants et étudiez les résultats

# %%
# tree1
q0='/*'
printXPath(tree1,q0)
# Out:
# <RoisdeFrance>
#   <Roi>
#     <nom>Francois I</nom>
#     <fils>
#       <Roi id="r3">
#         <nom>Henri II</nom>
#         <epouse>
#           <Reine id="r5">
#             <nom>Catherine de Medicis</nom>
#             <fils>
#               <Roi id="r4">
#                 <nom>Francois II</nom>
#                 <epouse>
#                   <Reine id="r6">
#                     <nom>Mary Stuart</nom>
#                     <epoux ref="r4"/>
#                   </Reine>
#                 </epouse>
#               </Roi>
#             </fils>
#             <fils>
#               <Roi id="r2">
#                 <nom>Charles IX</nom>
#               </Roi>
#             </fils>
#             <fils>
#               <Roi id="r9">
#                 <nom>Henry III</nom>
#               </Roi>
#             </fils>
#           </Reine>
#         </epouse>
#       </Roi>
#     </fils>
#   </Roi>
#   <Reine id="r8">
#     <nom>Elisabeth d Autriche</nom>
#     <epoux ref="r2"/>
#   </Reine>
# </RoisdeFrance>

# %%
# affichage graphique
displayXPath(tree1,q0,"res0")

# %%
# tous les rois
q1='//Roi'
printXPath(tree1,q1)
# Out:
# <Roi>
#   <nom>Francois I</nom>
#   <fils>
#     <Roi id="r3">
#       <nom>Henri II</nom>
#       <epouse>
#         <Reine id="r5">
#           <nom>Catherine de Medicis</nom>
#           <fils>
#             <Roi id="r4">
#               <nom>Francois II</nom>
#               <epouse>
#                 <Reine id="r6">
#                   <nom>Mary Stuart</nom>
#                   <epoux ref="r4"/>
#                 </Reine>
#               </epouse>
#             </Roi>
#           </fils>
#           <fils>
#             <Roi id="r2">
#               <nom>Charles IX</nom>
#             </Roi>
#           </fils>
#           <fils>
#             <Roi id="r9">
#               <nom>Henry III</nom>
#             </Roi>
#           </fils>
#         </Reine>
#       </epouse>
#     </Roi>
#   </fils>
# </Roi>
#
# <Roi id="r3">
#   <nom>Henri II</nom>
#   <epouse>
#     <Reine id="r5">
#       <nom>Catherine de Medicis</nom>
#       <fils>
#         <Roi id="r4">
#           <nom>Francois II</nom>
#           <epouse>
#             <Reine id="r6">
#               <nom>Mary Stuart</nom>
#               <epoux ref="r4"/>
#             </Reine>
#           </epouse>
#         </Roi>
#       </fils>
#       <fils>
#         <Roi id="r2">
#           <nom>Charles IX</nom>
#         </Roi>
#       </fils>
#       <fils>
#         <Roi id="r9">
#           <nom>Henry III</nom>
#         </Roi>
#       </fils>
#     </Reine>
#   </epouse>
# </Roi>
#
# <Roi id="r4">
#   <nom>Francois II</nom>
#   <epouse>
#     <Reine id="r6">
#       <nom>Mary Stuart</nom>
#       <epoux ref="r4"/>
#     </Reine>
#   </epouse>
# </Roi>
#
# <Roi id="r2">
#   <nom>Charles IX</nom>
# </Roi>
#
# <Roi id="r9">
#   <nom>Henry III</nom>
# </Roi>

# %%
# affichage graphique
displayXPath(tree1,q1,"res1")

# %%
# tous les rois 
q1='//Roi'
printXPath(tree2,q1)
# Out:
# <Roi>
#   <nom>Francois I</nom>
#   <fils ref="r3"/>
# </Roi>
#
# <Roi id="r3">
#   <nom>Henri II</nom>
#   <fils ref="r4"/>
#   <fils ref="r2"/>
#   <fils ref="r9"/>
#   <epouse ref="r5"/>
# </Roi>
#
# <Roi id="r4">
#   <nom>Francois II</nom>
#   <epouse ref="r6"/>
# </Roi>
#
# <Roi id="r2">
#   <nom>Charles IX</nom>
#   <epouse ref="r8"/>
# </Roi>
#
# <Roi id="r9">
#   <nom>Henry III</nom>
# </Roi>

# %%
# affichage graphique
displayXPath(tree2,q1,"res2")

# %%
# l'epouse de François II
q2a='//Roi[nom="Francois II"]/epouse'
printXPath(tree1,q2a)
# Out:
# <epouse>
#   <Reine id="r6">
#     <nom>Mary Stuart</nom>
#     <epoux ref="r4"/>
#   </Reine>
# </epouse>

# %%
# réécrire la requête précédente appliquée à tree2 
q2a='//Reine[epoux/@ref=//Roi[nom="Francois II"]/@id]'
printXPath(tree2,q2a)
# Out:
# <Reine id="r6">
#   <nom>Mary Stuart</nom>
#   <epoux ref="r4"/>
# </Reine>

# %% [markdown]
# **Exercice:** exprimez les requêtes suivantes sur tree1 et tree2

# %% [markdown]
# - le nom de l'épouse de François II

# %%
#Tree1
q2a='//Roi[nom="Francois II"]/epouse/Reine/nom'
printXPath(tree1,q2a)
#Tree2
q2a='//Reine[epoux/@ref=//Roi[nom="Francois II"]/@id]/nom'
printXPath(tree2,q2a)
# Out:
# <nom>Mary Stuart</nom>
#
# <nom>Mary Stuart</nom>

# %% [raw]
# <nom>Mary Stuart</nom>

# %% [markdown]
# - le nom de l'épouse de François II (sans tag)

# %%
#Tree1
q2a='//Roi[nom="Francois II"]/epouse/Reine/nom/text()'
printXPath(tree1,q2a)
#Tree2
q2a='//Reine[epoux/@ref=//Roi[nom="Francois II"]/@id]/nom/text()'
printXPath(tree2,q2a)
# Out:
# Mary Stuart
# Mary Stuart

# %% [raw]
# Mary Stuart

# %% [markdown]
# - les noms des rois et des reines

# %%
#Tree1
q2a='//*/nom'
printXPath(tree1,q2a)
#Tree2
q2a='//*/nom'
printXPath(tree2,q2a)
# Out:
# <nom>Francois I</nom>
#
# <nom>Henri II</nom>
#
# <nom>Catherine de Medicis</nom>
#
# <nom>Francois II</nom>
#
# <nom>Mary Stuart</nom>
#
# <nom>Charles IX</nom>
#
# <nom>Henry III</nom>
#
# <nom>Elisabeth d Autriche</nom>
#
# <nom>Francois I</nom>
#
# <nom>Henri II</nom>
#
# <nom>Francois II</nom>
#
# <nom>Charles IX</nom>
#
# <nom>Henry III</nom>
#
# <nom>Catherine de Medicis</nom>
#
# <nom>Mary Stuart</nom>
#
# <nom>Elisabeth d Autriche</nom>

# %% [raw]
# <nom>Francois I</nom>
# <nom>Henri II</nom>
# <nom>Francois II</nom>
# <nom>Charles IX</nom>
# <nom>Henry III</nom>
# <nom>Catherine de Medicis</nom>
# <nom>Mary Stuart</nom>
# <nom>Elisabeth d Autriche</nom>

# %% [markdown]
# - les noms des fils de Catherine de Medicis;

# %%
#Tree1
q2a='//Reine[nom="Catherine de Medicis"]/fils/Roi/nom'
printXPath(tree1,q2a)
#Tree2
q2a='//Roi[@id=//Reine[nom="Catherine de Medicis"]/fils/@ref]/nom'
printXPath(tree2,q2a)
# Out:
# <nom>Francois II</nom>
#
# <nom>Charles IX</nom>
#
# <nom>Henry III</nom>
#
# <nom>Francois II</nom>
#
# <nom>Charles IX</nom>
#
# <nom>Henry III</nom>

# %% [raw]
# <nom>Francois II</nom>
# <nom>Charles IX</nom>
# <nom>Henry III</nom>

# %% [markdown]
# - le nom de l’épouse de Henri II;

# %%
#Tree1
q2a='//Roi[nom="Henri II"]/epouse/Reine/nom'
printXPath(tree1,q2a)
#Tree2
q2a='//Reine[@id=//Roi[nom="Henri II"]/epouse/@ref]/nom'
printXPath(tree2,q2a)
# Out:
# <nom>Catherine de Medicis</nom>
#
# <nom>Catherine de Medicis</nom>

# %% [raw]
# <nom>Catherine de Medicis</nom>

# %% [markdown]
# - le nom de l’époux de Mary Stuart (attention il existe une référence);

# %%
#Tree1
q2a='//Roi[@id=//Reine[nom="Mary Stuart"]/epoux/@ref]/nom'
printXPath(tree1,q2a)
#Tree2
q2a='//Roi[@id=//Reine[nom="Mary Stuart"]/epoux/@ref]/nom'
printXPath(tree2,q2a)
# Out:
# <nom>Francois II</nom>
#
# <nom>Francois II</nom>

# %% [raw]
# <nom>Francois II</nom>

# %% [markdown]
# - le nom de l’époux d’Elisabeth d’Autriche;

# %%
#Tree1
q2a='//Roi[@id=//Reine[nom="Elisabeth d Autriche"]/epoux/@ref]/nom'
printXPath(tree1,q2a)
#Tree2
q2a='//Roi[@id=//Reine[nom="Elisabeth d Autriche"]/epoux/@ref]/nom'
printXPath(tree2,q2a)
# Out:
# <nom>Charles IX</nom>
#
# <nom>Charles IX</nom>

# %% [raw]
# <nom>Charles IX</nom>

# %% [markdown]
# - le nom de la belle mère de Mary Stuart (de la personne qui a un fils dont l’épouse s’appelle Mary Stuart);

# %%
#Tree1
q2a='//Reine[fils/Roi/epouse/Reine/nom="Mary Stuart"]/nom'
printXPath(tree1,q2a)
#Tree2
q2a='//Reine[fils/@ref=//Reine[nom="Mary Stuart"]/epoux/@ref]/nom'
printXPath(tree2,q2a)
# Out:
# <nom>Catherine de Medicis</nom>
#
# <nom>Catherine de Medicis</nom>

# %% [raw]
# <nom>Catherine de Medicis</nom>

# %% [markdown]
# - les noms des frères de Francois II;

# %%
#Tree1
q2a='//Reine[fils/Roi/nom="Francois II"]/fils/Roi[not(nom="Francois II")]/nom'
printXPath(tree1,q2a)
#Tree2
q2a='//Roi[@id=//Reine[fils/@ref=//Roi[nom="Francois II"]/@id]/fils/@ref][not (nom="Francois II")]/nom'
printXPath(tree2,q2a)
# Out:
# <nom>Charles IX</nom>
#
# <nom>Henry III</nom>
#
# <nom>Charles IX</nom>
#
# <nom>Henry III</nom>

# %% [raw]
# <nom>Charles IX</nom>
# <nom>Henry III</nom>

# %% [markdown]
# - les rois sans épouses;

# %%
#Tree1
q2a='//Roi[not (epouse) and not(@id=//Reine/epoux/@ref)]/nom '
printXPath(tree1,q2a)
#Tree2
q2a='//Roi[not (epouse) and not(@id=//Reine/epoux/@ref)]/nom '
printXPath(tree2,q2a)
# Out:
# <nom>Francois I</nom>
#
# <nom>Henry III</nom>
#
# <nom>Francois I</nom>
#
# <nom>Henry III</nom>

# %% [raw]
# <nom>Francois I</nom>
# <nom>Henry III</nom>

# %% [markdown]
# - les noms des rois et reines avec au moins un fils;

# %%
#Tree1
q2a='//*[fils]/nom'
printXPath(tree1,q2a)
#Tree2
q2a='//*[fils]/nom'
printXPath(tree2,q2a)
# Out:
# <nom>Francois I</nom>
#
# <nom>Catherine de Medicis</nom>
#
# <nom>Francois I</nom>
#
# <nom>Henri II</nom>
#
# <nom>Catherine de Medicis</nom>

# %% [raw]
# <nom>Francois I</nom>
# <nom>Catherine de Medicis</nom>

# %% [markdown]
# -  les noms des rois et reines sans fils;

# %%
#Tree1
q2a='//*[not(fils)]/nom'
printXPath(tree1,q2a)
#Tree2
q2a='//*[not(fils)]/nom'
printXPath(tree2,q2a)
# Out:
# <nom>Henri II</nom>
#
# <nom>Francois II</nom>
#
# <nom>Mary Stuart</nom>
#
# <nom>Charles IX</nom>
#
# <nom>Henry III</nom>
#
# <nom>Elisabeth d Autriche</nom>
#
# <nom>Francois II</nom>
#
# <nom>Charles IX</nom>
#
# <nom>Henry III</nom>
#
# <nom>Mary Stuart</nom>
#
# <nom>Elisabeth d Autriche</nom>

# %% [raw]
# <nom>Henri II</nom>
# <nom>Francois II</nom>
# <nom>Mary Stuart</nom>
# <nom>Charles IX</nom>
# <nom>Elisabeth d Autriche</nom>
# <nom>Henry III</nom>
